# %%
import pandas as pd 
import numpy as np

# %%
df1 = pd.read_csv(r"C:\Users\hp\Downloads\Content.csv")
df1
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1000 non-null   int64
#  1   Content ID  1000 non-null   object
#  2   User ID     1000 non-null   object
#  3   Type        1000 non-null   object
#  4   Category    1000 non-null   object
#  5   URL         801 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
df1.describe
# Out:
# <bound method NDFrame.describe of      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0      0
# Content ID      0
# User ID         0
# Type            0
# Category        0
# URL           199
# dtype: int64

# %%
df1_cleaned = df.dropna()

df['URL'] = df['URL'].fillna('Unknown')

# %%
df1['URL']
# Out:
# 0      https://socialbuzz.cdn.com/content/storage/975...
# 1      https://socialbuzz.cdn.com/content/storage/9f7...
# 2      https://socialbuzz.cdn.com/content/storage/230...
# 3      https://socialbuzz.cdn.com/content/storage/356...
# 4      https://socialbuzz.cdn.com/content/storage/01a...
#                              ...
# 995                                                  NaN
# 996    https://socialbuzz.cdn.com/content/storage/7a7...
# 997    https://socialbuzz.cdn.com/content/storage/435...
# 998    https://socialbuzz.cdn.com/content/storage/4e4...
# 999    https://socialbuzz.cdn.com/content/storage/75d...
# Name: URL, Length: 1000, dtype: object

# %%
df1_cleaned = df.drop_duplicates()
df1_cleaned
# Out:
#      Unnamed: 0                            Content ID  \
# 0             0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1             1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2             2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3             3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4             4  01ab84dd-6364-4236-abbb-3f237db77180
# ..          ...                                   ...
# 995         995  b4cef9ef-627b-41d7-a051-5961b0204ebb
# 996         996  7a79f4e4-3b7d-44dc-bdef-bc990740252c
# 997         997  435007a5-6261-4d8b-b0a4-55fdc189754b
# 998         998  4e4c9690-c013-4ee7-9e66-943d8cbd27b7
# 999         999  75d6b589-7fae-4a6d-b0d0-752845150e56
#
#                                   User ID   Type         Category  \
# 0    8d3cd87d-8a31-4935-9a4f-b319bfe05f31  photo         Studying
# 1    beb1f34e-7870-46d6-9fc7-2e12eb83ce43  photo   healthy eating
# 2    a5c65404-5894-4b87-82f2-d787cbee86b4  photo   healthy eating
# ...

# %%
import pandas as pd

df1 = pd.read_csv(r"C:\Users\hp\Downloads\Content.csv")
df2 = pd.read_csv(r"C:\Users\hp\Downloads\Reactions.csv")
df3 = pd.read_csv(r"C:\Users\hp\Downloads\ReactionTypes.csv")

# Concatenate the datasets
final_df = pd.concat([df1, df2, df3], ignore_index=True)
final_df
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2               2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3               3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4               4  01ab84dd-6364-4236-abbb-3f237db77180
# ...           ...                                   ...
# 26564          11                                   NaN
# 26565          12                                   NaN
# 26566          13                                   NaN
# 26567          14                                   NaN
# 26568          15                                   NaN
#
#                                     User ID       Type        Category  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31      photo        Studying
# 1      beb1f34e-7870-46d6-9fc7-2e12eb83ce43      photo  healthy eating
# 2      a5c65404-5894-4b87-82f2-d787cbee86b4      photo  healthy eating
# ...

# %%
final_df.isnull().sum()
# Out:
# Unnamed: 0        0
# Content ID       16
# User ID        3035
# Type            980
# Category      25569
# URL           25768
# Datetime       1016
# Sentiment     26553
# Score         26553
# dtype: int64

# %%
final_df_cleaned = final_df.dropna()

final_df['Content ID',] = final_df['Content ID'].fillna('Unknown')
final_df['User ID'] = final_df['User ID'].fillna('Unknown')
final_df['Category'] = final_df['Category'].fillna('Unknown')
final_df['URL'] = final_df['URL'].fillna('Unknown')
final_df['Datetime'] = final_df['Datetime'].fillna('Unknown')
final_df['Sentiment'] = final_df['Sentiment'].fillna('Unknown')
final_df['Score'] = final_df['Score'].fillna('Unknown')
final_df_cleaned
# Out:
#        Unnamed: 0                            Content ID  \
# 0               0  97522e57-d9ab-4bd6-97bf-c24d952602d2
# 1               1  9f737e0a-3cdd-4d29-9d24-753f4e3be810
# 2               2  230c4e4d-70c3-461d-b42c-ec09396efb3f
# 3               3  356fff80-da4d-4785-9f43-bc1261031dc6
# 4               4  01ab84dd-6364-4236-abbb-3f237db77180
# ...           ...                                   ...
# 26564          11                               Unknown
# 26565          12                               Unknown
# 26566          13                               Unknown
# 26567          14                               Unknown
# 26568          15                               Unknown
#
#                                     User ID       Type        Category  \
# 0      8d3cd87d-8a31-4935-9a4f-b319bfe05f31      photo        Studying
# 1      beb1f34e-7870-46d6-9fc7-2e12eb83ce43      photo  healthy eating
# 2      a5c65404-5894-4b87-82f2-d787cbee86b4      photo  healthy eating
# ...

# %%
top_5_categories = df['Category'].value_counts().head(5)
top_5_categories
# Out:
# Category
# technology    71
# animals       67
# travel        67
# culture       63
# science       63
# Name: count, dtype: int64

# %%
import pandas as pd

# Read the CSV file into a DataFrame
#df = pd.read_csv(r"C:\Users\hp\Downloads\Accenture task.csv")

# Convert the DataFrame to an Excel file
df.to_excel(r"C:\Users\hp\Downloads\top_5_categories.xlsx", index=False)
